# %%
import pandas as pd

# %%
import numpy as np

# %%
titanic=pd.read_csv("/Users/apple/Desktop/Titanic.csv")

# %%
titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
titanic.shape
# Out:
# (891, 12)

# %%
titanic.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
titanic.isnull().any()
# Out:
# PassengerId    False
# Survived       False
# Pclass         False
# Name           False
# Sex            False
# Age             True
# SibSp          False
# Parch          False
# Ticket         False
# Fare           False
# Cabin           True
# Embarked        True
# dtype: bool

# %%
titanic.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
del titanic['Name']

# %%
titanic.head()
# Out:
#    PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch  \
# 0            1         0       3    male  22.0      1      0
# 1            2         1       1  female  38.0      1      0
# 2            3         1       3  female  26.0      0      0
# 3            4         1       1  female  35.0      1      0
# 4            5         0       3    male  35.0      0      0
#
#              Ticket     Fare Cabin Embarked
# 0         A/5 21171   7.2500   NaN        S
# 1          PC 17599  71.2833   C85        C
# 2  STON/O2. 3101282   7.9250   NaN        S
# 3            113803  53.1000  C123        S
# 4            373450   8.0500   NaN        S

# %%
del titanic['Ticket']

# %%
titanic.head()
# Out:
#    PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch     Fare Cabin  \
# 0            1         0       3    male  22.0      1      0   7.2500   NaN
# 1            2         1       1  female  38.0      1      0  71.2833   C85
# 2            3         1       3  female  26.0      0      0   7.9250   NaN
# 3            4         1       1  female  35.0      1      0  53.1000  C123
# 4            5         0       3    male  35.0      0      0   8.0500   NaN
#
#   Embarked
# 0        S
# 1        C
# 2        S
# 3        S
# 4        S

# %%
del titanic['Cabin']

# %%
titanic.head()
# Out:
#    PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch     Fare Embarked
# 0            1         0       3    male  22.0      1      0   7.2500        S
# 1            2         1       1  female  38.0      1      0  71.2833        C
# 2            3         1       3  female  26.0      0      0   7.9250        S
# 3            4         1       1  female  35.0      1      0  53.1000        S
# 4            5         0       3    male  35.0      0      0   8.0500        S

# %%
del titanic['Fare']

# %%
titanic.head()
# Out:
#    PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch Embarked
# 0            1         0       3    male  22.0      1      0        S
# 1            2         1       1  female  38.0      1      0        C
# 2            3         1       3  female  26.0      0      0        S
# 3            4         1       1  female  35.0      1      0        S
# 4            5         0       3    male  35.0      0      0        S

# %%
def getNumber(str):
    if str=="male":
        return 0
    else:
        return 1
titanic['Gender']=titanic['Sex'].apply(getNumber)

# %%
titanic.head()
# Out:
#    PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch Embarked  Gender
# 0            1         0       3    male  22.0      1      0        S       0
# 1            2         1       1  female  38.0      1      0        C       1
# 2            3         1       3  female  26.0      0      0        S       1
# 3            4         1       1  female  35.0      1      0        S       1
# 4            5         0       3    male  35.0      0      0        S       0

# %%
del titanic['Sex']

# %%
titanic.head()
# Out:
#    PassengerId  Survived  Pclass   Age  SibSp  Parch Embarked  Gender
# 0            1         0       3  22.0      1      0        S       0
# 1            2         1       1  38.0      1      0        C       1
# 2            3         1       3  26.0      0      0        S       1
# 3            4         1       1  35.0      1      0        S       1
# 4            5         0       3  35.0      0      0        S       0

# %%
titanic.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Age            177
# SibSp            0
# Parch            0
# Embarked         2
# Gender           0
# dtype: int64

# %%
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  SibSp  Parch Embarked  Gender
# 0            1         0       3      1      0        S       0
# 1            2         1       1      1      0        C       1
# 2            3         1       3      0      0        S       1
# 3            4         1       1      1      0        S       1
# 4            5         0       3      0      0        S       0

# %%
titanic.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# SibSp          0
# Parch          0
# Embarked       2
# Gender         0
# dtype: int64

# %%
survivedS=titanic[titanic.Embarked=='S'][titanic.Survived==1].shape[0]
survivedC=titanic[titanic.Embarked=='C'][titanic.Survived==1].shape[0]
print(survivedS)
print(survivedC)
# Out:
# 217
# 93
# /var/folders/r6/7yndlk8j0bs4d5d8m5jf3gb40000gn/T/ipykernel_6188/3286962953.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   survivedS=titanic[titanic.Embarked=='S'][titanic.Survived==1].shape[0]
# /var/folders/r6/7yndlk8j0bs4d5d8m5jf3gb40000gn/T/ipykernel_6188/3286962953.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   survivedC=titanic[titanic.Embarked=='C'][titanic.Survived==1].shape[0]

# %%
survivedS=titanic[titanic.Embarked=='S'][titanic.Survived==0].shape[0]
survivedC=titanic[titanic.Embarked=='C'][titanic.Survived==0].shape[0]
print(survivedS)
print(survivedC)
# Out:
# 427
# 75
# /var/folders/r6/7yndlk8j0bs4d5d8m5jf3gb40000gn/T/ipykernel_6188/733527311.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   survivedS=titanic[titanic.Embarked=='S'][titanic.Survived==0].shape[0]
# /var/folders/r6/7yndlk8j0bs4d5d8m5jf3gb40000gn/T/ipykernel_6188/733527311.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   survivedC=titanic[titanic.Embarked=='C'][titanic.Survived==0].shape[0]

# %%
titanic.dropna(inplace=True)

# %%
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  SibSp  Parch Embarked  Gender
# 0            1         0       3      1      0        S       0
# 1            2         1       1      1      0        C       1
# 2            3         1       3      0      0        S       1
# 3            4         1       1      1      0        S       1
# 4            5         0       3      0      0        S       0

# %%
titanic.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# SibSp          0
# Parch          0
# Embarked       0
# Gender         0
# dtype: int64

# %%
import matplotlib.pyplot as plt

# %%
from matplotlib import style

# %%
males=(titanic['Gender']==0).sum()
Females=(titanic['Gender']==1).sum()

# %%
print(males)
print(Females)
# Out:
# 577
# 312

# %%
p=[males,Females]

# %%
plt.pie(p,labels=['male','Female'],colors=['green','yellow'],explode=(0.15,0),startangle=0)
plt.axis('equal')
plt.show()

# %%
MaleS=titanic[titanic.Gender==0][titanic.Survived==1].shape[0]
print(MaleS)
MaleN=titanic[titanic.Gender==0][titanic.Survived==0].shape[0]
print(MaleN)
FemaleS=titanic[titanic.Gender==1][titanic.Survived==1].shape[0]
print(FemaleS)
FemaleN=titanic[titanic.Gender==1][titanic.Survived==0].shape[0]
print(FemaleN)
chart=[MaleS,MaleN,FemaleS,FemaleN]
colors=['lightskyblue','yellowgreen','Yellow','Orange']
labels=["Survived Male","Not Survived Male","Survived Female","Not Survived Female"]
explode=[0,0.05,0,0.1]
plt.pie(chart,labels=labels,colors=colors,explode=explode,startangle=100,counterclock=False,autopct="%.2f%%")
plt.axis("equal")
plt.show()
# Out:
# 109
# 468
# 231
# 81
# /var/folders/r6/7yndlk8j0bs4d5d8m5jf3gb40000gn/T/ipykernel_6188/261965170.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   MaleS=titanic[titanic.Gender==0][titanic.Survived==1].shape[0]
# /var/folders/r6/7yndlk8j0bs4d5d8m5jf3gb40000gn/T/ipykernel_6188/261965170.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   MaleN=titanic[titanic.Gender==0][titanic.Survived==0].shape[0]
# /var/folders/r6/7yndlk8j0bs4d5d8m5jf3gb40000gn/T/ipykernel_6188/261965170.py:5: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   FemaleS=titanic[titanic.Gender==1][titanic.Survived==1].shape[0]
# /var/folders/r6/7yndlk8j0bs4d5d8m5jf3gb40000gn/T/ipykernel_6188/261965170.py:7: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   FemaleN=titanic[titanic.Gender==1][titanic.Survived==0].shape[0]
